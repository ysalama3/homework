# %% [markdown]
# **Part 1: In Class Challenge Continue, the shell**
# Get the data sets
# We are going to work with data from
# Cooney C.R., Bright J.A., Capp E.J.R., Chira A.M., Hughes E.C., Moody C.J.A., Nouri L.O., Varley Z.K., Thomas G.H. 2017.
# Mega-evolutionary dynamics of the adaptive radiation of birds. Nature.
# The paper is available here
# We want the data from Figure 1 which is available from this Nature link
# You will also need a list of ALL of the bird species. Lets use the checklist from the Cornell Lab of Ornithology here.

# %% [markdown]
# **Questions (can be answered using shell or python commands)**
#
# 1-How many families are in this file?
# 2-Which family has the most species represented?
# 3-How many families have only a single species in them?
# 4-How many families are present in the eBird data?
# 5-How many species are in each family of the eBird data?

# %% [markdown]
# codes:
# eeb177-student@eeb177-VirtualBox:~/Desktop/eeb-177/homework$ tail -n+4 formatted.nature.csv | cut -d "," -f 3 | wc -l
# 2028
# # q1
#
#
# ```
# tail -n+4 formatted.nature.csv | cut -d "," -f 3 | sort | uniq | wc -l
# ```
#
# 194
#
# # q2
#
# ```
# tail -n+4 formatted.nature.csv | cut -d "," -f 3 | sort | uniq -c | sort -n -r
#     102 Trochilidae
# ```
#
# # q3
#
# ```
# tail -n+4 formatted.nature.csv | cut -d "," -f 3 | sort | uniq -c | grep -w "1" -c
# 60
# ```
#
# # q4
#
# ```
# tail -n+4 formatted.ebird.csv | cut -d "," -f 8 | sort | uniq | wc -l
# 239
# ```
#
# # q5
#
# ```
# tail -n+4 formatted.ebird.csv | cut -d "," -f 8 | sort | uniq -c | sort -n
# ```
#       1 Anseranatidae (Magpie Goose)
#       1 Balaenicipitidae (Shoebill)
#       1 Donacobiidae (Donacobius)
#       1 Dromadidae (Crab Plover)
#       1 Dulidae (Palmchat)
#       1 Elachuridae (Spotted Elachura)
#       1 Eulacestomatidae (Ploughbill)
#       1 Eupetidae (Rail-babbler)
#       1 Eurypygidae (Sunbittern)
#       1 Hylocitreidae (Hylocitrea)
#       1 Hypocoliidae (Hypocolius)
#       1 Ibidorhynchidae (Ibisbill)
#       1 Ifritidae (Ifrita)
#       1 Leptosomidae (Cuckoo-Roller)
#       1 Notiomystidae (Stitchbird)
#       1 Opisthocomidae (Hoatzin)
#       1 Oxyruncidae (Sharpbill)
#       1 Panuridae (Bearded Reedling)
#       1 Pedionomidae (Plains-wanderer)
#       1 Peucedramidae (Olive Warbler)
#       1 Pityriaseidae (Bristlehead)
#       1 Pluvianellidae (Magellanic Plover)
#       1 Pluvianidae (Egyptian Plover)
#       1 Rhagologidae (Mottled Berryhunter)
#       1 Rhynochetidae (Kagu)
#       1 Sagittariidae (Secretary-bird)
#       1 Sapayoidae (Sapayoa)
#       1 Scopidae (Hamerkop)
#       1 Steatornithidae (Oilbird)
#       1 Struthionidae (Ostriches)
#       1 Tichodromidae (Wallcreeper)
#       1 Urocynchramidae (Przevalski's Pinktail)
#       2 Atrichornithidae (Scrub-birds)
#       2 Bucorvidae (Ground-Hornbills)
#       2 Cariamidae (Seriemas)
#       2 Chaetopidae (Rockjumpers)
#       2 Chionidae (Sheathbills)
#       2 Corcoracidae (White-winged Chough and Apostlebird)
#       2 Irenidae (Fairy-bluebirds)
#       2 Machaerirhynchidae (Boatbills)
#       2 Melampittidae (Melampittas)
#       2 Menuridae (Lyrebirds)
#       2 Paramythiidae (Tit Berrypecker and Crested Berrypecker)
#       2 Picathartidae (Rockfowl)
#       2 Semnornithidae (Toucan-Barbets)
#       3 Anhimidae (Screamers)
#       3 Aramidae (Limpkin)
#       3 Buphagidae (Oxpeckers)
#       3 Cnemophilidae (Satinbirds)
#       3 Dasyornithidae (Bristlebirds)
#       3 Heliornithidae (Finfoots)
#       3 Mesitornithidae (Mesites)
#       3 Mohouidae (Whiteheads)
#       3 Oreoicidae (Australo-Papuan Bellbirds)
#       3 Orthonychidae (Logrunners)
#       3 Rostratulidae (Painted-Snipes)
#       4 Acanthisittidae (New Zealand Wrens)
#       4 Anhingidae (Anhingas)
#       4 Bombycillidae (Waxwings)
#       4 Casuariidae (Cassowaries and Emu)
#       4 Falcunculidae (Shrike-tit)
#       4 Hyliotidae (Hyliotas)
#       4 Melanopareiidae (Crescentchests)
#       4 Nicatoridae (Nicators)
#       4 Ptiliogonatidae (Silky-flycatchers)
#       4 Rheidae (Rheas)
#       4 Strigopidae (New Zealand Parrots)
#       4 Thinocoridae (Seedsnipes)
#       5
#       5 Aegithinidae (Ioras)
#       5 Brachypteraciidae (Ground-Rollers)
#       5 Callaeidae (Wattlebirds)
#       5 Hemiprocnidae (Treeswifts)
#       5 Mohoidae (Hawaiian Honeyeaters)
#       5 Pandionidae (Osprey)
#       5 Philepittidae (Asities)
#       5 Pomatostomidae (Pseudo-Babblers)
#       5 Promeropidae (Sugarbirds)
#       5 Psophodidae (Whipbirds and Wedgebills)
#       5 Upupidae (Hoopoes)
#       6 Fregatidae (Frigatebirds)
#       6 Todidae (Todies)
#       7 Apterygidae (Kiwis)
#       7 Coliidae (Mousebirds)
#       7 Pnoepygidae (Cupwings)
#       8 Gaviidae (Loons)
#       8 Neosittidae (Sittellas)
#       8 Phoenicopteridae (Flamingos)
#       9 Calcariidae (Longspurs and Snow Buntings)
#       9 Climacteridae (Australasian Treecreepers)
#      10 Calyptomenidae (African and Green Broadbills)
#      10 Cinclidae (Dippers)
#      10 Nyctibiidae (Potoos)
#      11 Bernieridae (Malagasy Warblers)
#      11 Burhinidae (Thick-knees)
#      11 Eurylaimidae (Asian and Grauer's Broadbills)
#      11 Phaethontidae (Tropicbirds)
#      11 Psophiidae (Trumpeters)
#      11 Stenostiridae (Fairy Flycatchers)
#      12 Cathartidae (New World Vultures)
#      12 Melanocharitidae (Berrypeckers and Longbills)
#      12 Pardalotidae (Pardalotes)
#      13 Chloropseidae (Leafbirds)
#      13 Conopophagidae (Gnateaters)
#      13 Jacanidae (Jacanas)
#      13 Pelecanidae (Pelicans)
#      13 Phoeniculidae (Woodhoopoes and Scimitar-bills)
#      13 Regulidae (Kinglets)
#      14 Aegothelidae (Owlet-nightjars)
#      14 Artamidae (Woodswallows)
#      14 Cinclosomatidae (Quail-thrushes and Jewel-babblers)
#      14 Prunellidae (Accentors)
#      15 Numididae (Guineafowl)
#      15 Sarothruridae (Flufftails)
#      16 Haematopodidae (Oystercatchers)
#      16 Remizidae (Penduline-Tits)
#      16 Stercorariidae (Skuas and Jaegers)
#      17 Formicariidae (Antthrushes)
#      18 Capitonidae (New World Barbets)
#      18 Coraciidae (Rollers)
#      19 Certhiidae (Treecreepers)
#      19 Recurvirostridae (Stilts and Avocets)
#      19 Turnicidae (Buttonquail)
#      20 Indicatoridae (Honeyguides)
#      21 Momotidae (Motmots)
#      21 Spheniscidae (Penguins)
#      21 Sulidae (Boobies and Gannets)
#      23 Aegithalidae (Long-tailed Tits)
#      23 Galbulidae (Jacamars)
#      23 Glareolidae (Pratincoles and Coursers)
#      23 Gruidae (Cranes)
#      23 Megapodiidae (Megapodes)
#      23 Podargidae (Frogmouths)
#      23 Viduidae (Indigobirds)
#      24 Pteroclidae (Sandgrouse)
#      25 Ciconiidae (Storks)
#      25 Macrosphenidae (African Warblers)
#      26 Cacatuidae (Cockatoos)
#      26 Cracticidae (Bellmagpies and Allies)
#      28 Ptilonorhynchidae (Bowerbirds)
#      30 Polioptilidae (Gnatcatchers)
#      31 Podicipedidae (Grebes)
#      33 Diomedeidae (Albatrosses)
#      33 Meropidae (Bee-eaters)
#      34 Otididae (Bustards)
#      35 Tytonidae (Barn-Owls)
#      37 Sittidae (Nuthatches)
#      40 "Alcidae (Auks
#      40 Dicruridae (Drongos)
#      40 Maluridae (Fairywrens)
#      41 Musophagidae (Turacos)
#      42 Cettiidae (Bush-Warblers and Allies)
#      42 Megalaimidae (Asian Barbets)
#      44 Threskiornithidae (Ibises and Spoonbills)
#      44 Tityridae (Tityras and Allies)
#      45 Paradisaeidae (Birds-of-Paradise)
#      45 Platysteiridae (Wattle-eyes and Batises)
#      46 Mimidae (Mockingbirds and Thrashers)
#      46 Oriolidae (Old World Orioles)
#      46 "Paradoxornithidae (Parrotbills
#      47 Sylviidae (Sylviid Warblers)
#      48 Bucconidae (Puffbirds)
#      50 Hydrobatidae (Storm-Petrels)
#      50 Odontophoridae (New World Quail)
#      54 "Vangidae (Vangas
#      55 Passeridae (Old World Sparrows)
#      56 Phalacrocoracidae (Cormorants and Shags)
#      57 Dicaeidae (Flowerpeckers)
#      57 Tinamidae (Tinamous)
#      58 Petroicidae (Australasian Robins)
#      59 Laniidae (Shrikes)
#      59 Pittidae (Pittas)
#      61 Trogonidae (Trogons)
#      64 Lybiidae (African Barbets)
#      64 Ramphastidae (Toucans)
#      67 Pipridae (Manakins)
#      67 "Timaliidae (Tree-Babblers
#      70 Pellorneidae (Ground Babblers and Allies)
#      71 Pachycephalidae (Whistlers and Allies)
#      72 "Cracidae (Guans
#      72 Malaconotidae (Bushshrikes and Allies)
#      74 Bucerotidae (Hornbills)
#      74 Grallariidae (Antpittas)
#      75 Rhinocryptidae (Tapaculos)
#      76 Acanthizidae (Thornbills and Allies)
#      76 Cotingidae (Cotingas)
#      76 Locustellidae (Grassbirds and Allies)
#      80 Acrocephalidae (Reed-Warblers and Allies)
#      86 Rhipiduridae (Fantails)
#      90 Charadriidae (Plovers and Lapwings)
#      93 Cardinalidae (Cardinals and Allies)
#      98 "Paridae (Tits
#     108 "Vireonidae (Vireos
#     109 Falconidae (Falcons and Caracaras)
#     111 Campephagidae (Cuckooshrikes)
#     119 Phylloscopidae (Leaf Warblers)
#     124 Caprimulgidae (Nightjars and Allies)
#     126 "Ardeidae (Herons
#     130 Motacillidae (Wagtails and Pipits)
#     136 Monarchidae (Monarch Flycatchers)
#     144 Procellariidae (Shearwaters and Petrels)
#     146 Hirundinidae (Swallows)
#     147 Sturnidae (Starlings)
#     147 "Zosteropidae (White-eyes
#     148 Alaudidae (Larks)
#     152 Apodidae (Swifts)
#     154 Ploceidae (Weavers and Allies)
#     158 Scolopacidae (Sandpipers and Allies)
#     161 Alcedinidae (Kingfishers)
#     165 Troglodytidae (Wrens)
#     166 Icteridae (Troupials and Allies)
#     171 Leiothrichidae (Laughingthrushes and Allies)
#     176 Estrildidae (Waxbills and Allies)
#     190 "Corvidae (Crows
#     190 Nectariniidae (Sunbirds and Spiderhunters)
#     200 Pycnonotidae (Bulbuls)
#     203 "Rallidae (Rails
#     206 Cuculidae (Cuckoos)
#     208 Meliphagidae (Honeyeaters)
#     209 "Laridae (Gulls
#     222 Cisticolidae (Cisticolas and Allies)
#     226 Psittaculidae (Old World Parrots)
#     228 Parulidae (New World Warblers)
#     240 "Phasianidae (Pheasants
#     251 Psittacidae (New World and African Parrots)
#     295 Turdidae (Thrushes and Allies)
#     298 Thamnophilidae (Typical Antbirds)
#     318 Emberizidae (Buntings and New World Sparrows)
#     318 Strigidae (Owls)
#     325 "Fringillidae (Finches
#     364 "Anatidae (Ducks
#     370 Picidae (Woodpeckers)
#     386 "Accipitridae (Hawks
#     425 Columbidae (Pigeons and Doves)
#     452 Furnariidae (Ovenbirds and Woodcreepers)
#     457 Muscicapidae (Old World Flycatchers)
#     472 Trochilidae (Hummingbirds)
#     505 Thraupidae (Tanagers and Allies)
#     617 Tyrannidae (Tyrant Flycatchers)

# %% [markdown]
# ****Part II. Bird data in python****

# %% [markdown]
# **Questions**
# 1. Create a dictionary where the keys are the species in the nature data set and the values are families. Write a loop thatwill give the output Species XX belongs to Family YY for all key-value pairs
# 2. Do the same for the ebird data.
# 3. Write another loop that reports the number of species in each family in the ebird data set with this output There areXX total species in Family YY . You may find the Counter object useful for this.

# %% [markdown]
# **I created a csv file and extracted two columns (species and families) into the file so that it's easier to work with**

# %% [markdown]
# **I then created an empty dictionary and matched the two columns as key and corresponding value.**

# %%
import csv
reader = csv.reader(open("/home/eeb177-student/Desktop/eeb-177/homework/natureoutput3.csv", "r"))
nature_dict={}
for row in reader:
    k, v = row
    nature_dict[k] = v
    
print(nature_dict)
# Out:
# {'Podoces_hendersoni': 'Corvidae', 'Xenocopsychus_ansorgei': 'Muscicapidae', 'Lafresnaya_lafresnayi': 'Trochilidae', 'Telespiza_cantans': 'Fringillidae', 'Phaenostictus_mcleannani': 'Thamnophilidae', 'Locustella_luscinioides': 'Sylviidae', 'Aratinga_weddellii': 'Psittacidae', 'Corythaeola_cristata': 'Musophagidae', 'Aphelocephala_leucopsis': 'Acan
Archilochus_colubris': 'Trochilidae', 'Zimmerius_vilissimus': 'Tyrannidae', 'Melierax_metabates': 'Accipitridae', 'Iridophanes_pulcherrimus': 'Thraupidae', 'Neophema_elegans': 'Psittacidae', 'Heteromunia_pectoralis': 'Estrildidae', 'Epimachus_bruijnii': 'Paradisaeidae', 'Dinemellia_dinemelli': 'Ploceidae', 'Androdon_aequatorialis': 'Trochilidae', 'Calypte_anna': 'Trochilidae', 'Chlorornis_riefferii': 'Thraupidae', 'Telacanthura_ussheri': 'Apodidae', 'Aprosmictus_jonquillaceus': 'Psittacidae', 'Sasia_abnormis': 'Picidae', 'Tetraophasis_szechenyii': 'Phasianidae', 'Woodfordia_superciliosa': 'Zosteropidae', 'Siphonorhis_brewsteri': 'Caprimulgidae', 'Euryptila_subcinnamomea': 'Cisticolidae', 'Sappho_sparganura': 'Trochilidae', 'Oreostruthus_fuliginosus': 'Estrildidae', 'Canirallus_oculeus': 'Rallidae', 'Cichladusa_arquata': 'Muscicapidae', 'Claravis_pretiosa': 'Columbidae', 'Doricha_enicura': 'Trochilidae', 'Miliaria_calandra': 'Emberizidae', 'Chlorophanes_spiza': 'Thraupidae', 'Nisaetus_cirrhatus': 'Accipitridae', 'Argusianus_argus': 'Phasianidae', ' ...

# %%
import csv
reader = csv.reader(open("/home/eeb177-student/Desktop/eeb-177/homework/ebirdoutput3.csv", "r"))
ebird_dict={}
for row in reader:
    k, v = row
    ebird_dict[k] = v
    
    
print(ebird_dict)
# Out:
# {'bawnig6': 'Caprimulgidae (Nightjars and Allies)', 'attwoo4': 'Picidae (Woodpeckers)', 'x00634': 'Picidae (Woodpeckers)', 'yerwar3': 'Parulidae (New World Warblers)', 'taurac1': 'Musophagidae (Turacos)', 'x00767': 'Columbidae (Pigeons and Doves)', 'comyel4': 'Parulidae (New World Warblers)', 'chrcha1': 'Muscicapidae (Old World Flycatchers)', 'swift1': 'Apodidae (Swifts)', 'brntin1': 'Tinamidae (Tinamous)', 'crecur2': 'Cracidae (Guans\nsalcur1,Cracidae (Guans', 'punlor1': 'Psittaculidae (Old World Parrots)', 'borwht1': 'Muscicapidae (Old World Flycatchers)', 'bkbwoo': 'Picidae (Woodpeckers)', 'stiwre1': 'Acanthisittidae (New Zealand Wrens)', 'viowoo1': 'Phoeniculidae (Woodhoopoes and Scimitar-bills)', 'eurcoo': 'Rallidae (Rails\ny00680,Rallidae (Rails', 'x00707': 'Psittaculidae (Old World Parrots)', 'bluqua1': 'Phasianidae (Pheasants\nsnmqua2,Phasianidae (Pheasants', 'grepot1': 'Nyctibiidae (Potoos)', 'grecoc1': 'Turdidae (Thrushes and Allies)', 'bncwoo2': 'Picidae (Woodpeckers)', 'whbblt1': 'Paridae (Tits\nashtit2,Paridae (Tits', 'guityr1': 'Tyrannidae (Tyrant Flycatchers)', 'sablar3': 'Alaudidae (Larks)', 'ruwwoo1': 'Picidae (Woodpeckers)', 'whrswi1': 'Apodidae (Swifts)', 'resque2': 'Trogonidae (Trogons)', 'apalis1': 'Cisticolidae (Cisticolas and Allies)', 'redcro13': 'Fring
# %% [markdown]
# **Part II**

# %%
#create a list containing families
mylist = nature_dict[v]
#count how many times family names are repeated in that list
counted = Counter(mylist)

# run a loop that states how many species are in each family
for v in nature_dict:
    print("there are " + str(counted) + "total species in family " + str(nature_dict[v]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-2981b88ac899> in <module>()
#       1 #create a list containing families
# ----> 2 mylist = nature_dict[v]
#       3 #count how many times family names are repeated in that list
#       4 counted = Counter(mylist)
#       5
#
# KeyError: 'Fringillidae (Finches\ncinwhe1,Passeridae (Old World Sparrows)\nsaxspa1,Passeridae (Old World Sparrows)\nhouspa,Passeridae (Old World Sparrows)\nitaspa1,Passeridae (Old World Sparrows)\nx00873,Passeridae (Old World Sparrows)\ny00692,Passeridae (Old World Sparrows)\nspaspa1,Passeridae (Old World Sparrows)\nx00645,Passeridae (Old World Sparrows)\ny00829,Passeridae (Old World Sparrows)\ny01017,Passeridae (Old World Sparrows)\nsinspa1,Passeridae (Old World Sparrows)\nsomspa1,Passeridae (Old World Sparrows)\nrusspa2,Passeridae (Old World Sparrows)\nplbspa1,Passeridae (Old World Sparrows)\ndesspa1,Passeridae (Old World Sparrows)\ndesspa5,Passeridae (Old World Sparrows)\ndesspa6,Passeridae (Old World Sparrows)\ncavspa1,Passeridae (Old World Sparrows)\naakspa1,Passeridae (Old World Sparrows)\nsocspa1,Passeridae (Old World Sparrows)\ngrrspa1,Passeridae (Old World Sparrows)\nkerspa2,Passeridae (Old World Sparrows)\nshrspa1,Passeridae (Old World Sparrows)\nkorspa1,Passeridae (Old World Sparrows)\ncapspa1,Passeridae (Old World Sparrows)\ngyhspa1,Passeridae (Old World Sparrows)\nswaspa2,Passeridae (Old World Sparrows)\npabspa1,Passeridae (Old World Sparrows)\nswaspa1,Passeridae (Old World Sparrows)\nsghspa2,Passeridae (Old World Sparrows)\ndesspa2,Passeridae (Old World Sparrows)\ndesspa3,Passeridae (Old World Sparrows)\ndesspa4,Passeridae (Old World Sparrows)\neutspa,Passeridae (Old World Sparrows)\nx00754,Passeridae (Old World Sparrows)\ny00764,Passeridae (Old World Sparrows)\nx00874,Passeridae (Old World Sparrows)\nsugspa1,Passeridae (Old World Sparrows)\nargspa2,Passeridae (Old World Sparrows)\nchespa1,Passeridae (Old World Sparrows)\npasser2,Passeridae (Old World Sparrows)\nyespet1,Passeridae (Old World Sparrows)\nchspet1,Passeridae (Old World Sparrows)\nyetpet1,Passeridae (Old World Sparrows)\nbuspet1,Passeridae (Old World Sparrows)\nrocpet1,Passeridae (Old World Sparrows)\npalroc1,Passeridae (Old World Sparrows)\nwhwsno1,Passeridae (Old World Sparrows)\ntibsno2,Passeridae (Old World Sparrows)\nblwsno1,Passeridae (Old World Sparrows)\nwhrsno1,Passeridae (Old World Sparrows)\npedsno1,Passeridae (Old World Sparrows)\nrunsno1,Passeridae (Old World Sparrows)\nblasno1,Passeridae (Old World Sparrows)\nafgsno1,Passeridae (Old World Sparrows)\nwbbwea1,Ploceidae (Weavers and Allies)\nrbbwea1,Ploceidae (Weavers and Allies)\nwhbwea1,Ploceidae (Weavers and Allies)\nspfwea1,Ploceidae (Weavers and Allies)\nscawea1,Ploceidae (Weavers and Allies)\nwbswea1,Ploceidae (Weavers and Allies)\nwhbspw1,Ploceidae (Weavers and Allies)\nwhbspw2,Ploceidae (Weavers and Allies)\nwhbspw3,Ploceidae (Weavers and Allies)\nwhbspw4,Ploceidae (Weavers and Allies)\nccswea1,Ploceidae (Weavers and Allies)\ncbswea1,Ploceidae (Weavers and Allies)\ndsswea1,Ploceidae (Weavers and Allies)\nrutwea1,Ploceidae (Weavers and Allies)\ngyhsow1,Ploceidae (Weavers and Allies)\nbcswea1,Ploceidae (Weavers and Allies)\nsocwea1,Ploceidae (Weavers and Allies)\nrecmal2,Ploceidae (Weavers and Allies)\nbltmal1,Ploceidae (Weavers and Allies)\nbalmal2,Ploceidae (Weavers and Allies)\nracmal1,Ploceidae (Weavers and Allies)\nrevmal1,Ploceidae (Weavers and Allies)\nibamal1,Ploceidae (Weavers and Allies)\nrebmal1,Ploceidae (Weavers and Allies)\ngramal1,Ploceidae (Weavers and Allies)\ncremal1,Ploceidae (Weavers and Allies)\nrehmal1,Ploceidae (Weavers and Allies)\nmalimb1,Ploceidae (Weavers and Allies)\nrehwea1,Ploceidae (Weavers and Allies)\nyelwea2,Ploceidae (Weavers and Allies)\nberwea2,Ploceidae (Weavers and Allies)\nbagwea1,Ploceidae (Weavers and Allies)\nbagwea2,Ploceidae (Weavers and Allies)\nbagwea3,Ploceidae (Weavers and Allies)\nbagwea4,Ploceidae (Weavers and Allies)\nbagwea5,Ploceidae (Weavers and Allies)\nbkcwea1,Ploceidae (Weavers and Allies)\nbanwea1,Ploceidae (Weavers and Allies)\nbatwea1,Ploceidae (Weavers and Allies)\nlitwea1,Ploceidae (Weavers and Allies)\nslbwea1,Ploceidae (Weavers and Allies)\nloawea1,Ploceidae (Weavers and Allies)\nblnwea1,Ploceidae (Weavers and Allies)\nb ...

# %%
#create a list containing families
mylist = ebird_dict[v]
#count how many times family names are repeated in that list
counted = Counter(mylist)

# run a loop that states how many species are in each family
for v in ebird_dict:
    print("there are " + str(counted) + "total species in family " + str(nature_dict[v]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-78d235e272b2> in <module>()
#       1 #create a list containing families
# ----> 2 mylist = ebird_dict[v]
#       3 #count how many times family names are repeated in that list
#       4 counted = Counter(mylist)
#       5
#
# KeyError: 'Fringillidae (Finches\ncinwhe1,Passeridae (Old World Sparrows)\nsaxspa1,Passeridae (Old World Sparrows)\nhouspa,Passeridae (Old World Sparrows)\nitaspa1,Passeridae (Old World Sparrows)\nx00873,Passeridae (Old World Sparrows)\ny00692,Passeridae (Old World Sparrows)\nspaspa1,Passeridae (Old World Sparrows)\nx00645,Passeridae (Old World Sparrows)\ny00829,Passeridae (Old World Sparrows)\ny01017,Passeridae (Old World Sparrows)\nsinspa1,Passeridae (Old World Sparrows)\nsomspa1,Passeridae (Old World Sparrows)\n
ceidae (Weavers and Allies)\ncremal1,Ploceidae (Weavers and Allies)\nrehmal1,Ploceidae (Weavers and Allies)\nmalimb1,Ploceidae (Weavers and Allies)\nrehwea1,Ploceidae (Weavers and Allies)\nyelwea2,Ploceidae (Weavers and Allies)\nberwea2,Ploceidae (Weavers and Allies)\nbagwea1,Ploceidae (Weavers and Allies)\nbagwea2,Ploceidae (Weavers and Allies)\nbagwea3,Ploceidae (Weavers and Allies)\nbagwea4,Ploceidae (Weavers and Allies)\nbagwea5,Ploceidae (Weavers and Allies)\nbkcwea1,Ploceidae (Weavers and Allies)\nbanwea1,Ploceidae (Weavers and Allies)\nbatwea1,Ploceidae (Weavers and Allies)\nlitwea1,Ploceidae (Weavers and Allies)\nslbwea1,Ploceidae (Weavers and Allies)\nloawea1,Ploceidae (Weavers and Allies)\nblnwea1,Ploceidae (Weavers and Allies)\nb ...

# %% [markdown]
# **Part III**
# Percentage of amino acid residues,
# part one

# %%
protein = "MSRSLLLRFLLFLLLLPPLP"
aa = "R"
aa_count = protein.count(aa)
protein_length = len(protein)
percentage = aa_count * 100 / protein_length
print(percentage)
# Out:
# 10.0

# %%
def get_aa_percentage(protein, aa):
    aa_count = protein.count(aa)
    protein_length = len(protein)
    percentage = aa_count * 100 / protein_length
    return percentage

# %%
assert get_aa_percentage("MSRSLLLRFLLFLLLLPPLP", "M") == 5
assert get_aa_percentage("MSRSLLLRFLLFLLLLPPLP", "r") == 10
assert get_aa_percentage("msrslllrfllfllllpplp", "L") == 50
assert get_aa_percentage("MSRSLLLRFLLFLLLLPPLP", "Y") == 0
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-16-c9c5ceae3187> in <module>()
#       1 assert get_aa_percentage("MSRSLLLRFLLFLLLLPPLP", "M") == 5
# ----> 2 assert get_aa_percentage("MSRSLLLRFLLFLLLLPPLP", "r") == 10
#       3 assert get_aa_percentage("msrslllrfllfllllpplp", "L") == 50
#       4 assert get_aa_percentage("MSRSLLLRFLLFLLLLPPLP", "Y") == 0
#
# AssertionError:

# %%
def get_aa_percentage(protein, aa):
    protein = protein.upper()
    aa = aa.upper()
    aa_count = protein.count(aa)
    protein_length = len(protein)
    percentage = aa_count * 100 / protein_length
    return percentage

# %%
assert get_aa_percentage("MSRSLLLRFLLFLLLLPPLP", "M") == 5
assert get_aa_percentage("MSRSLLLRFLLFLLLLPPLP", "r") == 10
assert get_aa_percentage("msrslllrfllfllllpplp", "L") == 50
assert get_aa_percentage("MSRSLLLRFLLFLLLLPPLP", "Y") == 0

# %% [markdown]
# **Percentage of amino acid residues, part two**

# %%
protein = "MSRSLLLRFLLFLLLLPPLP"
aa_list = ['M', 'L', 'F']

total = 0 
for aa in aa_list: 
    print("counting number of " + aa)
    aa = aa.upper() 
    aa_count = protein.count(aa) 
    total = total + aa_count 
    print("running total is " + str(total))
    percentage = total * 100 / len(protein)
    print("final percentage is " + str(percentage))
# Out:
# counting number of M
# running total is 1
# final percentage is 5.0
# counting number of L
# running total is 11
# final percentage is 55.0
# counting number of F
# running total is 13
# final percentage is 65.0

# %%
def get_aa_percentage(protein, aa_list): 
    protein = protein.upper() 
    protein_length = len(protein) 
    total = 0 
    for aa in aa_list: 
        aa = aa.upper() 
        aa_count = protein.count(aa) 
        total = total + aa_count 
    percentage = total * 100 / protein_length 
    return percentage

# %%
def get_aa_percentage(protein, aa_list=['A','I','L','M','F','W','Y','V']):
    protein = protein.upper() 
    protein_length = len(protein) 
    total = 0 
    for aa in aa_list: 
        aa = aa.upper() 
        aa_count = protein.count(aa) 
        total = total + aa_count 
    percentage = total * 100 / protein_length 
    return percentage
